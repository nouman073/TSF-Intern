# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('globalterrorismdb_0718dist.csv',encoding='latin1')
# Out:
# C:\Users\Noumann\AppData\Local\Temp\ipykernel_10192\3655520895.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('globalterrorismdb_0718dist.csv',encoding='latin1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
columns_to_drop=['approxdate','eventid','related']
df.drop(columns_to_drop,axis=1,inplace=True,)

# %%
print('Most effect Regions : ',df.region_txt.value_counts().index[0])
print("Most effect Countries form torrorism Attects : ",df.country_txt.value_counts().idxmax())
print("Most effect City form attack : " , df.city.value_counts().index[1])
print('Most terrorist group involved in attacks : ', df.gname.value_counts().index[1])
print("Totel number of killed people : " ,df.nkill.sum())
print("Year with most of attacks : ", df.iyear.value_counts().idxmax())
print("Most of Attacks Types : ",df.attacktype1_txt.value_counts().index[0])
# Out:
# Most effect Regions :  Middle East & North Africa
# Most effect Countries form torrorism Attects :  Iraq
# Most effect City form attack :  Baghdad
# Most terrorist group involved in attacks :  Taliban
# Totel number of killed people :  411868.0
# Year with most of attacks :  2014
# Most of Attacks Types :  Bombing/Explosion

# %%
plt.subplots(figsize=(20, 10))
sns.countplot(x='iyear', data=df)
plt.title('Attacks by years')
plt.ylabel('Attacks')
plt.xticks(rotation=(90))
plt.show()
plt.xticks(rotation=(45))

# %%
plt.subplots(figsize=(20, 10))
sns.countplot(x='imonth', data=df)
plt.title('Attacks by months')
plt.ylabel('Attacks')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='region_txt',data=df)
plt.xticks(rotation=(20))
plt.show()

# %%
df.dtypes.head(50)
# Out:
# iyear                 int64
# imonth                int64
# iday                  int64
# extended              int64
# resolution           object
# country               int64
# country_txt          object
# region                int64
# region_txt           object
# provstate            object
# city                 object
# latitude            float64
# longitude           float64
# specificity         float64
# vicinity              int64
# location             object
# summary              object
# crit1                 int64
# crit2                 int64
# crit3                 int64
# doubtterr           float64
# alternative         float64
# alternative_txt      object
# multiple            float64
# success               int64
# suicide               int64
# attacktype1           int64
# attacktype1_txt      object
# attacktype2         float64
# attacktype2_txt      object
# attacktype3         float64
# attacktype3_txt      object
# targtype1             int64
# ...

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df.city.value_counts()[1:15].index, y=df.city.value_counts()[0:14].values, data=df)
plt.title('Most affect Cities')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df.country_txt.value_counts()[0:15].index,y=df.nkill.value_counts()[0:15].values,data=df)
# Out:
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['iyear', 'imonth', 'iday', 'extended', 'resolution', 'country',
#        'country_txt', 'region', 'region_txt', 'provstate',
#        ...
#        'nreleased', 'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource',
#        'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype='object', length=132)

# %%
print(df.loc[df.country_txt == 'Pakistan', 'nkill'].sum())
df.loc[df.country_txt == 'Iraq' , 'nkill'].sum()
# Out:
# 23822.0
# 78589.0
