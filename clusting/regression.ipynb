# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_linear=df[['age','fare']]

# %%
df.shape
# Out:
# (891, 15)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_linear.age.fillna(value=df_linear['age'].mean(), inplace=True)
#y.fare.fillna(value= y['fare'].mean(), inplace=True)
# Out:
# C:\Users\Noumann\AppData\Local\Temp\ipykernel_17604\1574441605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_linear.age.fillna(value=df_linear['age'].mean(), inplace=True)

# %%
df_linear.isnull().sum()*100 / len(df_linear)
# Out:
# age     0.0
# fare    0.0
# dtype: float64

# %%
sns.lmplot(data=df_linear,x='age', y='fare')

# %%
sns.boxplot(data=df_linear,y='age')
# Out:
# <AxesSubplot: ylabel='age'>

# %%
df_linear=df_linear[(df['age'] > 8 ) & (df_linear['age'] < 50 )]

# %%
sns.boxplot(data=df_linear, y='fare')
# Out:
# <AxesSubplot: ylabel='fare'>

# %%
df_linear=df_linear[(df['fare'] > 1 ) & (df_linear['fare'] < 50 )]
# Out:
# C:\Users\Noumann\AppData\Local\Temp\ipykernel_17604\4126918070.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_linear=df_linear[(df['fare'] > 1 ) & (df_linear['fare'] < 50 )]

# %%
sns.lmplot(data=df_linear,y='fare',x='age')

# %%
X=df_linear[['age']]
y=df_linear['fare']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

#call the model
model=LinearRegression()

# train the model
model.fit(X,y)
a=input("enter the age")
a=int(a)
# prediction
model.predict([[a]])
# Out:
# C:\Users\Noumann\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([12.29416806])

# %%
#Lecture
#ASSingment
#camp x
# Out:
# 56

# %%
y.isnull().sum()*100 / len(y)
# Out:
# fare    0.0
# dtype: float64

# %%
x.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
X.shape
# Out:
# (891, 1)

# %%
y.shape
# Out:
# (891, 1)

# %%
# plot
sns.lmplot

# %%
model.score(X_test, y_test)
